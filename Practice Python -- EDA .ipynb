# %%
# Importing all libraries
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# Importing dataset
ds = pd.read_csv(r'C:\Users\HARSH\00. Projects\Datasets for projects\healthcare_Investments.csv')
ds.head()
# Out:
#   Location  Time  Hospital_Stay  MRI_Units  CT_Scanners  Hospital_Beds
# 0      AUS  1992            6.6       1.43        16.71           1.43
# 1      AUS  1994            6.4       2.36        18.48           2.36
# 2      AUS  1995            6.5       2.89        20.55           2.89
# 3      AUS  1996            6.4       2.96        21.95           2.96
# 4      AUS  1997            6.2       3.53        23.34           3.53

# %%
ds.info()
ds.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       518 non-null    object
#  1   Time           518 non-null    int64
#  2   Hospital_Stay  518 non-null    float64
#  3   MRI_Units      518 non-null    float64
#  4   CT_Scanners    518 non-null    float64
#  5   Hospital_Beds  518 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 24.4+ KB
# (518, 6)

# %%
#
fig = plt.figure(figsize=(15, 4))
g = sns.countplot(data=ds, x="Location",
                  order = ds['Location'].value_counts().index)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set_title("records for each location")
# Out:
# Text(0.5, 1.0, 'records for each location')

# %%
#Plotting average and variance for different parameters with respect to time.

ds_list = ['Hospital_Stay','Hospital_Beds','MRI_Units','CT_Scanners']

ds.groupby('Time')[ds_list].mean().plot()
ds.groupby('Time')[ds_list].var().plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
#Using heatmap to know relation between various parameters
sns.heatmap(ds.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
print("COMPLETED")
# Out:
# COMPLETED

# %% [markdown]
# #                                       This Project is Completed
