# %%
class Bank_Account():
    def __init__(self):
        self.balance = 0
        
    
    def menu_options(self):
        print(" ---- Welcome to the Bank ----       ")
        print("=====================================")
        print("1. Open a new account")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Check Customers & Balance")
        print("5. transfer Money")
        print("6. Exit/Quit")
        print("=====================================")

    def account_info(self):
        full_name = input("Enter your full name:")
        import random 
        x = random.randrange(10000, 999999)
        y = input("Enter your password:")
        self.balance = int(input("Enter initial amount to start your account: "))
        account_number = x
        print("************")
        print("Hurray! Your Account has been created!")
        print(f'your account number is: {x}')
        print(f'initial balance is ${self.balance}')
        print("************")
        return self.balance
              
    def deposit_money(self):
        deposited_money = int(input("Enter the amount you want to deposit: "))
        self.balance += deposited_money
        print(f'your new balance is ${self.balance}')
        return self.balance
        
    def withdraw_money(self):
        wdrw_amt = int(input("enter the money you want to Withdraw: ")) 
        if self.balance > wdrw_amt:
            self.balance -= wdrw_amt
            print(f'Your remaining balance is ${self.balance}')    
        else:
            print("Sorry! You do not have enough balance")
        return self.balance
        
    def transfer_money(self):
        Acc_num = int(input("Enter the account number: "))
        transfer_amount = int(input("enter the money you want to transfer: ")) 
        if self.balance > transfer_amount:
            self.balance -= transfer_amount
            print("Funds tranferred" )
            print(f'your new balance is {self.balance}')    
        else:
            print("Sorry! You do not have enough balance")
        return self.balance
            
    def check_balance(self):
        print(f'Your current balance is {self.balance}')
        return self.balance

# %%
b = Bank_Account()
exit_num = 6
print("Enter number 7 to select different options!")
while True:
    
    a = int(input("Enter the number to go to selection: "))
    if a != exit_num:
        print("=====================================")
        print("=====================================")
        print("=====================================")
        
        if a == 1:
            b.account_info()
        elif a == 2:
            b.deposit_money()
        elif a == 3:
            b.withdraw_money()
        elif a == 4:
            b.check_balance()
        elif a == 5:   
            b.transfer_money()
        elif a == 7:
            b.menu_options()
        print("=====================================")
        print("Enter the number 7 to see the other options")
        print("If you want to exit enter the number: 6")
        print("=====================================")
    else:
        print("Thank you for using our services")
        break
# Out:
# Enter number 7 to select different options!
# Enter the number to go to selection: 7
# ...
#  ---- Welcome to the Bank ----
# ...
# 1. Open a new account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Customers & Balance
# 5. transfer Money
# 6. Exit/Quit
# ...
# Enter the number 7 to see the other options
# If you want to exit enter the number: 6
# ...
# Enter the number to go to selection: 1
# ...
# Enter your full name:Harsh
# Enter your password:123456
# Enter initial amount to start your account: 5000
# ************
# Hurray! Your Account has been created!
# your account number is: 927590
# initial balance is $5000
# ************
# ...
# Enter the number 7 to see the other options
# If you want to exit enter the number: 6
# ...
# Enter the number to go to selection: 2
# ...
# Enter the amount you want to deposit: 2000
# your new balance is $7000
# ...
# Enter the number 7 to see the other options
# If you want to exit enter the number: 6
# ...
# Enter the number to go to selection: 3
# ...
# enter the money you want to Withdraw: 2500
# ...
